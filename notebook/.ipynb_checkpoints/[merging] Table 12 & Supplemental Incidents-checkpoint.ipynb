# %%
import pandas as pd

# %%
incident_supplemental = pd.read_csv('../output/incidents_supplemented_2.csv', index_col=0)
agency_reporting = pd.read_csv('../output/table_12_2004-2015.csv', index_col=0)

# %%
incident_supplemental.head()
# Out:
#    date       state  religion  sexual_orientation  disability  gender  \
# 0  2015     Alabama         0                   2           0     0.0
# 1  2015      Alaska         0                   1           0     0.0
# 2  2015     Arizona        52                  57           5     0.0
# 3  2015    Arkansas         0                   2           0     0.0
# 4  2015  California       191                 188           4     1.0
#
#    gender_identity  race_corrected   est_pop  \
# 0              0.0             8.0   4858979
# 1              NaN             7.0    738432
# 2              0.0           162.0   6828065
# 3              0.0             3.0   2978204
# 4             26.0           427.0  39144818
#
#   race_religion_ethnicity_enh_penalty          ...           \
# 0                                 YES          ...
# 1                                 YES          ...
# 2                                 YES          ...
# 3                                  NO          ...
# 4                                 YES          ...
#
#   institutional_vandalism_statute_present cross_burning_statute_present  \
# 0                                       1                             1
# 1                                       0                             0
# 2                                       1                             1
# 3                                       1                             0
# 4                                       1                             1
#
#   all_count race_corrected_per_capita religion_per_capita  \
# 0      10.0                  0.000002            0.000000
# 1       8.0                  0.000009            0.000000
# 2     276.0                  0.000024            0.000008
# 3       5.0                  0.000001            0.000000
# 4     837.0                  0.000011            0.000005
#
#    sexual_orientation_per_capita  disability_per_capita  gender_per_capita  \
# 0                   4.116091e-07           0.000000e+00       0.000000e+00
# 1                   1.354221e-06           0.000000e+00       0.000000e+00
# 2                   8.347899e-06           7.322719e-07       0.000000e+00
# 3                   6.715457e-07           0.000000e+00       0.000000e+00
# 4                   4.802679e-06           1.021847e-07       2.554617e-08
#
#    gender_identity_per_capita  all_count_per_capita
# 0                0.000000e+00              0.000002
# 1                         NaN              0.000011
# 2                0.000000e+00              0.000040
# 3                0.000000e+00              0.000002
# 4                6.642003e-07              0.000021
#
# [5 rows x 28 columns]

# %%
incident_supplemental.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 593 entries, 0 to 592
# Data columns (total 28 columns):
# date                                       593 non-null int64
# state                                      593 non-null object
# religion                                   593 non-null int64
# sexual_orientation                         593 non-null int64
# disability                                 593 non-null int64
# gender                                     148 non-null float64
# gender_identity                            147 non-null float64
# race_corrected                             593 non-null float64
# est_pop                                    593 non-null int64
# race_religion_ethnicity_enh_penalty        593 non-null object
# sexual_orientation_enh_penalty             593 non-null object
# gender_enh_penalty                         593 non-null object
# gender_identity_enh_penalty                593 non-null object
# disability_enh_penalty                     593 non-null object
# other_enh_penalty                          593 non-null object
# civil_action_statute_present               593 non-null int64
# data_collection_statute_present            593 non-null int64
# police_training_statute_present            593 non-null int64
# institutional_vandalism_statute_present    593 non-null int64
# cross_burning_statute_present              593 non-null int64
# all_count                                  593 non-null float64
# race_corrected_per_capita                  593 non-null float64
# religion_per_capita                        593 non-null float64
# sexual_orientation_per_capita              593 non-null float64
# disability_per_capita                      593 non-null float64
# gender_per_capita                          148 non-null float64
# gender_identity_per_capita                 147 non-null float64
# all_count_per_capita                       593 non-null float64
# dtypes: float64(11), int64(10), object(7)
# memory usage: 134.4+ KB

# %%
agency_reporting.head()
# Out:
#   Participating State  date  Number of Participating Agencies  \
# 1             Alabama  2004                                51
# 2              Alaska  2004                                 1
# 3             Arizona  2004                                82
# 4            Arkansas  2004                               192
# 5          California  2004                               725
#
#    Population Covered  Agencies Submitting Incident Reports  \
# 1            527267.0                                     3
# 2            273714.0                                     1
# 3           5554597.0                                    19
# 4           1632735.0                                    50
# 5          35893799.0                                   245
#
#    Total Number of Incidents Reported
# 1                                   3
# 2                                   9
# 3                                 224
# 4                                  93
# 5                                1393

# %%
agency_reporting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 599 entries, 1 to 50
# Data columns (total 6 columns):
# Participating State                     599 non-null object
# date                                    599 non-null int64
# Number of Participating Agencies        599 non-null int64
# Population Covered                      599 non-null float64
# Agencies Submitting Incident Reports    599 non-null int64
# Total Number of Incidents Reported      599 non-null int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 32.8+ KB

# %%
agency_reporting = agency_reporting.rename(columns={'Participating State' : 'state'})

# %%
agency_reporting['state'] = agency_reporting['state'].replace('District of Columbia', 'DC')

# %%
combined_data = pd.merge(incident_supplemental, agency_reporting, how='outer', on=['state', 'date'])

# %%
combined_data['percent_of_population_covered'] = combined_data['Population Covered'] / combined_data['est_pop']

# %%
combined_data.head()
# Out:
#    date       state  religion  sexual_orientation  disability  gender  \
# 0  2015     Alabama       0.0                 2.0         0.0     0.0
# 1  2015      Alaska       0.0                 1.0         0.0     0.0
# 2  2015     Arizona      52.0                57.0         5.0     0.0
# 3  2015    Arkansas       0.0                 2.0         0.0     0.0
# 4  2015  California     191.0               188.0         4.0     1.0
#
#    gender_identity  race_corrected     est_pop  \
# 0              0.0             8.0   4858979.0
# 1              NaN             7.0    738432.0
# 2              0.0           162.0   6828065.0
# 3              0.0             3.0   2978204.0
# 4             26.0           427.0  39144818.0
#
#   race_religion_ethnicity_enh_penalty              ...                \
# 0                                 YES              ...
# 1                                 YES              ...
# 2                                 YES              ...
# 3                                  NO              ...
# 4                                 YES              ...
#
#   sexual_orientation_per_capita disability_per_capita gender_per_capita  \
# 0                  4.116091e-07          0.000000e+00      0.000000e+00
# 1                  1.354221e-06          0.000000e+00      0.000000e+00
# 2                  8.347899e-06          7.322719e-07      0.000000e+00
# 3                  6.715457e-07          0.000000e+00      0.000000e+00
# 4                  4.802679e-06          1.021847e-07      2.554617e-08
#
#   gender_identity_per_capita all_count_per_capita  \
# 0               0.000000e+00             0.000002
# 1                        NaN             0.000011
# 2               0.000000e+00             0.000040
# 3               0.000000e+00             0.000002
# 4               6.642003e-07             0.000021
#
#    Number of Participating Agencies  Population Covered  \
# 0                                34           1252146.0
# 1                                33            734820.0
# 2                               101           6622880.0
# 3                               279           2754543.0
# 4                               730          39137326.0
#
#    Agencies Submitting Incident Reports  Total Number of Incidents Reported  \
# 0                                     3                                  10
# 1                                     4                                   8
# 2                                    21                                 276
# 3                                     4                                   5
# 4                                   213                                 837
#
#    percent_of_population_covered
# 0                       0.257697
# 1                       0.995109
# 2                       0.969950
# 3                       0.924901
# 4                       0.999809
#
# [5 rows x 33 columns]

# %%
combined_data.to_csv('../output/incident_aggregated_with_agencies.csv')
